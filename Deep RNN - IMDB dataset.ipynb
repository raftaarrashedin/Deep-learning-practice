# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense

# %%
# loading the imdb dataset
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 0s 0us/step

# %%
# pad sequence to have same length
X_train = pad_sequences(X_train, maxlen=100)
X_test = pad_sequences(X_test, maxlen=100)

# %%
# Defining the RNN model
model = Sequential([
    Embedding(10000, 32, input_length=100),
    SimpleRNN(5, return_sequences=True),
    SimpleRNN(5),
    Dense(1, activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 32)           320000
#
#  simple_rnn (SimpleRNN)      (None, 100, 5)            190
#
#  simple_rnn_1 (SimpleRNN)    (None, 5)                 55
#
#  dense (Dense)               (None, 1)                 6
#
# =================================================================
# Total params: 320251 (1.22 MB)
# Trainable params: 320251 (1.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer = 'Adam',loss = 'binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs = 5, batch_size = 32, validation_split=0.2)
# Out:
# Epoch 1/5
# 625/625 [==============================] - 29s 43ms/step - loss: 0.5393 - accuracy: 0.7290 - val_loss: 0.4591 - val_accuracy: 0.7936
# Epoch 2/5
# 625/625 [==============================] - 25s 40ms/step - loss: 0.3507 - accuracy: 0.8598 - val_loss: 0.4117 - val_accuracy: 0.8236
# Epoch 3/5
# 625/625 [==============================] - 24s 39ms/step - loss: 0.2415 - accuracy: 0.9136 - val_loss: 0.4598 - val_accuracy: 0.8188
# Epoch 4/5
# 625/625 [==============================] - 24s 38ms/step - loss: 0.1688 - accuracy: 0.9434 - val_loss: 0.4919 - val_accuracy: 0.8120
# Epoch 5/5
# 625/625 [==============================] - 27s 42ms/step - loss: 0.1222 - accuracy: 0.9615 - val_loss: 0.5504 - val_accuracy: 0.8002
