# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement_of_MANUU.csv')

# %%
df.head()
# Out:
#    Student_ID  CGPA   IQ  Placement
# 0           1   6.8  123          1
# 1           2   5.9  106          0
# 2           3   5.3  121          0
# 3           4   7.4  132          1
# 4           5   5.8  142          0

# %%
print(df.shape)
# Out:
# (100, 4)

# %%
# these codes are used in dataset of placement_data_full_class 
#refine_df = df.drop(['gender','ssc_p','ssc_b','hsc_p','hsc_b','hsc_s','degree_t','workex','etest_p','specialisation'], axis =1)
#refine_df.head()
#refine_df = refine_df.rename(columns = {"sl_no" : "S_No"})
#refine_df = refine_df.rename(columns = {"degree_p" : "resume_Score"})
#refine_df = refine_df.rename(columns = {"mba_p" : "percentage"})
#refine_df.head()
#sns.scatterplot(refine_df['resume_Score'],refine_df['cgpa'], hue = refine_df['status'])

# %%
sns.scatterplot(df['CGPA'],df['IQ'], hue = df['Placement'])
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CGPA', ylabel='IQ'>

# %%
X = df.iloc[:,1:3]
y = df.iloc[:,-1]

# %%
X.head()
# Out:
#    CGPA   IQ
# 0   6.8  123
# 1   5.9  106
# 2   5.3  121
# 3   7.4  132
# 4   5.8  142

# %%
X.shape
# Out:
# (100, 2)

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: Placement, dtype: int64

# %%
y.shape
# Out:
# (100,)

# %%
X = df.iloc[:,1:3].values
y = df.iloc[:,-1].values

# %%
# Importing Perceptron from sklearn
from sklearn.linear_model import Perceptron

# %%
model = Perceptron()

# %%
model.fit(X,y)
# Out:
# Perceptron()

# %%
model.coef_
# Out:
# array([[1218.5, -193. ]])

# %% [markdown]
# Here we understand that my W1 = 1218.5, and W2 = -193

# %%
model.intercept_
# Out:
# array([-7.])

# %% [markdown]
# Here my b is -7

# %%
model = Perceptron(max_iter = 100)
model = model.fit(X,y)

# %%
print(" Classes of the model",model.classes_)
# Out:
#  Classes of the model [0 1]

# %%
print(" Intercept of the decision boundary ",model.intercept_)
# Out:
#  Intercept of the decision boundary  [-7.]

# %%
print(" Coefficient of the decision boundary ",model.coef_)
# Out:
#  Coefficient of the decision boundary  [[1218.5 -193. ]]

# %%
from mlxtend.plotting import plot_decision_regions

# %%
# # from mlxtend.evaluate import plot_decision_regions
# def plot_decision_boundary(clf, X, Y, cmap='Paired_r'):
#     h = 0.02
#     x_min, x_max = X[:,0].min() - 10*h, X[:,0].max() + 10*h
#     y_min, y_max = X[:,1].min() - 10*h, X[:,1].max() + 10*h
#     xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
#                          np.arange(y_min, y_max, h))
#     Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
#     Z = Z.reshape(xx.shape)

#     plt.figure(figsize=(5,5))
#     plt.contourf(xx, yy, Z, cmap=cmap, alpha=0.25)
#     plt.contour(xx, yy, Z, colors='k', linewidths=0.7)
#     plt.scatter(X[:,0], X[:,1], c=Y, cmap=cmap, edgecolors='k');

# %%
# from sklearn.impute import SimpleImputer
# imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean',verbose=0)
# imputer = imputer.fit(X.iloc[:, 1:3])
# X.iloc[:, 1:3] = imputer.transform(X.iloc[:, 1:3])
# Plotting decision regions
# fig, ax = plt.subplots()
# # Decision region for feature 3 = 1.5
# value = 1.5
# # Plot training sample with feature 3 = 1.5 +/- 0.75
# width = 0.75

# %%
#plot_decision_regions(X, y, clf=model,
                    
                      # filler_feature_values={2: value},
                      # filler_feature_ranges={2: width},
                      # legend=2, ax=ax)
plot_decision_regions(X, y, clf=model)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-123-4c8065cc18ee> in <module>
#       4                       # filler_feature_ranges={2: width},
#       5                       # legend=2, ax=ax)
# ----> 6 plot_decision_regions(X, y, clf=model)
#
# /usr/local/lib/python3.9/dist-packages/mlxtend/plotting/decision_regions.py in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, res, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, scatter_highlight_kwargs)
#     242                antialiased=True)
#     243
# --> 244     ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())
#     245
#     246     # Scatter training data samples
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_base.py in axis(self, emit, *args, **kwargs)
# ...
