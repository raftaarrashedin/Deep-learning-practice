# %%
import tensorflow as tf

# %%
# first variable
var = tf.Variable(0)

# %%
add_operation = tf.add(var,1)
add_operation
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=1>

# %%
update_operation = tf.assign(var, add_operation)
# update_operation = tf.append(tf.assign(var, add_operation))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-6f29b7e0967b> in <module>
# ----> 1 update_operation = tf.assign(var, add_operation)
#       2 # update_operation = tf.append(tf.assign(var, add_operation))
#
# AttributeError: module 'tensorflow' has no attribute 'assign'

# %%
with tf.Session() as sess :
  sess.run(tf.global_variables_initializer())

  for _ in range(3) :
    sess.run(add_operation)
    print(sess.run(var))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-a82ec78d2c1d> in <module>
# ----> 1 with tf.Session() as sess :
#       2   sess.run(tf.global_variables_initializer())
#       3
#       4   for _ in range(3) :
#       5     sess.run(add_operation)
#
# AttributeError: module 'tensorflow' has no attribute 'Session'
